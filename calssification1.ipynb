# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_excel('/content/Bank_file1.xlsx')
df.head()
# Out:
#    ID  age          job  marital          education
# 0  C1   30  blue-collar  married           basic.9y
# 1  C2   39     services   single        high.school
# 2  C3   25     services  married        high.school
# 3  C4   38     services  married           basic.9y
# 4  C5   47       admin.  married  university.degree

# %%
df.shape
# Out:
# (4119, 5)

# %%
df1=pd.read_excel('/content/Bank_file2.xlsx')
df1.head()
# Out:
#    ID default  housing     loan    contact month
# 0  C1      no      yes       no   cellular   may
# 1  C2      no       no       no  telephone   may
# 2  C3      no      yes       no  telephone   jun
# 3  C4      no  unknown  unknown  telephone   jun
# 4  C5      no      yes       no   cellular   nov

# %%
df1.shape
# Out:
# (4119, 6)

# %%
df2=pd.read_excel('/content/Bank_target file.xlsx')
df2.head()
# Out:
#    ID approved
# 0  C1       no
# 1  C2       no
# 2  C3       no
# 3  C4       no
# 4  C5       no

# %%
df2.shape
# Out:
# (4119, 2)

# %%
df3=pd.read_excel('/content/bank_file3.xlsx')
df3.head()
# Out:
#    ID day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0  C1         fri       487         2    999         0  nonexistent
# 1  C2         fri       346         4    999         0  nonexistent
# 2  C3         wed       227         1    999         0  nonexistent
# 3  C4         fri        17         3    999         0  nonexistent
# 4  C5         mon        58         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0          -1.8          92.893          -46.2      1.313       5099.1
# 1           1.1          93.994          -36.4      4.855       5191.0
# 2           1.4          94.465          -41.8      4.962       5228.1
# 3           1.4          94.465          -41.8      4.959       5228.1
# 4          -0.1          93.200          -42.0      4.191       5195.8

# %%
df3.shape
# Out:
# (4119, 12)

# %%
df11=pd.merge(df,df1)
df11.head()
# Out:
#    ID  age          job  marital          education default  housing     loan  \
# 0  C1   30  blue-collar  married           basic.9y      no      yes       no
# 1  C2   39     services   single        high.school      no       no       no
# 2  C3   25     services  married        high.school      no      yes       no
# 3  C4   38     services  married           basic.9y      no  unknown  unknown
# 4  C5   47       admin.  married  university.degree      no      yes       no
#
#      contact month
# 0   cellular   may
# 1  telephone   may
# 2  telephone   jun
# 3  telephone   jun
# 4   cellular   nov

# %%
df12=pd.merge(df11,df3)
df12.head()
# Out:
#    ID  age          job  marital          education default  housing     loan  \
# 0  C1   30  blue-collar  married           basic.9y      no      yes       no
# 1  C2   39     services   single        high.school      no       no       no
# 2  C3   25     services  married        high.school      no      yes       no
# 3  C4   38     services  married           basic.9y      no  unknown  unknown
# 4  C5   47       admin.  married  university.degree      no      yes       no
#
#      contact month  ... duration  campaign  pdays  previous     poutcome  \
# 0   cellular   may  ...      487         2    999         0  nonexistent
# 1  telephone   may  ...      346         4    999         0  nonexistent
# 2  telephone   jun  ...      227         1    999         0  nonexistent
# 3  telephone   jun  ...       17         3    999         0  nonexistent
# 4   cellular   nov  ...       58         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0         -1.8          92.893          -46.2      1.313       5099.1
# 1          1.1          93.994          -36.4      4.855       5191.0
# 2          1.4          94.465          -41.8      4.962       5228.1
# 3          1.4          94.465          -41.8      4.959       5228.1
# 4         -0.1          93.200          -42.0      4.191       5195.8
#
# [5 rows x 21 columns]

# %%
final_df=pd.merge(df12,df2,)
final_df.head()
# Out:
#    ID  age          job  marital          education default  housing     loan  \
# 0  C1   30  blue-collar  married           basic.9y      no      yes       no
# 1  C2   39     services   single        high.school      no       no       no
# 2  C3   25     services  married        high.school      no      yes       no
# 3  C4   38     services  married           basic.9y      no  unknown  unknown
# 4  C5   47       admin.  married  university.degree      no      yes       no
#
#      contact month  ... campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   cellular   may  ...        2    999         0  nonexistent          -1.8
# 1  telephone   may  ...        4    999         0  nonexistent           1.1
# 2  telephone   jun  ...        1    999         0  nonexistent           1.4
# 3  telephone   jun  ...        3    999         0  nonexistent           1.4
# 4   cellular   nov  ...        1    999         0  nonexistent          -0.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed  approved
# 0         92.893          -46.2      1.313       5099.1        no
# 1         93.994          -36.4      4.855       5191.0        no
# 2         94.465          -41.8      4.962       5228.1        no
# 3         94.465          -41.8      4.959       5228.1        no
# 4         93.200          -42.0      4.191       5195.8        no
#
# [5 rows x 22 columns]

# %%
final_df.isnull().sum()
# Out:
# ID                0
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# approved          0
# dtype: int64

# %%
class_count = final_df['approved'].value_counts()

# Plot the distribution of the target class
plt.bar(class_count.index, class_count.values)
plt.xlabel('Target Class')
plt.ylabel('Number of Instances')
plt.title('Distribution of Target Class in Bank Train Data')
plt.show()

# %%
final_df.dtypes
# Out:
# ID                 object
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# approved           object
# dtype: object

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4119 entries, 0 to 4118
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              4119 non-null   object
#  1   age             4119 non-null   int64
#  2   job             4119 non-null   object
#  3   marital         4119 non-null   object
#  4   education       4119 non-null   object
#  5   default         4119 non-null   object
#  6   housing         4119 non-null   object
#  7   loan            4119 non-null   object
#  8   contact         4119 non-null   object
#  9   month           4119 non-null   object
#  10  day_of_week     4119 non-null   object
#  11  duration        4119 non-null   int64
#  12  campaign        4119 non-null   int64
#  13  pdays           4119 non-null   int64
#  14  previous        4119 non-null   int64
#  15  poutcome        4119 non-null   object
#  16  emp.var.rate    4119 non-null   float64
#  17  cons.price.idx  4119 non-null   float64
#  18  cons.conf.idx   4119 non-null   float64
#  19  euribor3m       4119 non-null   float64
#  20  nr.employed     4119 non-null   float64
#  21  approved        4119 non-null   object
# dtypes: float64(5), int64(5), object(12)
# memory usage: 740.1+ KB

# %%
final_df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %%
#correlation between features 
final_df.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.041299 -0.014169 -0.043425  0.050931
# duration        0.041299  1.000000 -0.085348 -0.046998  0.025724
# campaign       -0.014169 -0.085348  1.000000  0.058742 -0.091490
# pdays          -0.043425 -0.046998  0.058742  1.000000 -0.587941
# previous        0.050931  0.025724 -0.091490 -0.587941  1.000000
# emp.var.rate   -0.019192 -0.028848  0.176079  0.270684 -0.415238
# cons.price.idx -0.000482  0.016672  0.145021  0.058472 -0.164922
# cons.conf.idx   0.098135 -0.034745  0.007882 -0.092090 -0.051420
# euribor3m      -0.015033 -0.032329  0.159435  0.301478 -0.458851
# nr.employed    -0.041936 -0.044218  0.161037  0.381983 -0.514853
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.019192       -0.000482       0.098135  -0.015033
# duration           -0.028848        0.016672      -0.034745  -0.032329
# campaign            0.176079        0.145021       0.007882   0.159435
# pdays               0.270684        0.058472      -0.092090   0.301478
# previous           -0.415238       -0.164922      -0.051420  -0.458851
# emp.var.rate        1.000000        0.755155       0.195022   0.970308
# cons.price.idx      0.755155        1.000000       0.045835   0.657159
# cons.conf.idx       0.195022        0.045835       1.000000   0.276595
# euribor3m           0.970308        0.657159       0.276595   1.000000
# nr.employed         0.897173        0.472560       0.107054   0.942589
#
#                 nr.employed
# age               -0.041936
# duration          -0.044218
# campaign           0.161037
# pdays              0.381983
# previous          -0.514853
# emp.var.rate       0.897173
# cons.price.idx     0.472560
# cons.conf.idx      0.107054
# euribor3m          0.942589
# nr.employed        1.000000

# %%
# features correlation with  visualization using seaborn
sns.set(rc={'figure.figsize': (20, 10)})
sns .heatmap(final_df.corr(),annot=True,annot_kws={'size':12},cmap="YlGnBu")
plt.show()

# %%
#to get only numerical cols 
num=final_df._get_numeric_data() 
num.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   30       487         2    999         0          -1.8          92.893
# 1   39       346         4    999         0           1.1          93.994
# 2   25       227         1    999         0           1.4          94.465
# 3   38        17         3    999         0           1.4          94.465
# 4   47        58         1    999         0          -0.1          93.200
#
#    cons.conf.idx  euribor3m  nr.employed
# 0          -46.2      1.313       5099.1
# 1          -36.4      4.855       5191.0
# 2          -41.8      4.962       5228.1
# 3          -41.8      4.959       5228.1
# 4          -42.0      4.191       5195.8

# %%
#to get only cat cols and changing it as categorical from object 
cat=final_df.drop(num,axis=1)
cat=cat.astype('category')
cat.head()
# Out:
#    ID          job  marital          education default  housing     loan  \
# 0  C1  blue-collar  married           basic.9y      no      yes       no
# 1  C2     services   single        high.school      no       no       no
# 2  C3     services  married        high.school      no      yes       no
# 3  C4     services  married           basic.9y      no  unknown  unknown
# 4  C5       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week     poutcome approved
# 0   cellular   may         fri  nonexistent       no
# 1  telephone   may         fri  nonexistent       no
# 2  telephone   jun         wed  nonexistent       no
# 3  telephone   jun         fri  nonexistent       no
# 4   cellular   nov         mon  nonexistent       no

# %%
cat=cat.drop(['ID'],axis=1)

# %%
cat1=cat.drop(['approved'],axis=1)

# %%
#assign the target variable to t
t=cat.drop(cat1,axis=1)

# %%
cat_col=cat1.columns
cat_col
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %%
#converting the target variable as num by using Labelencoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in cat_col:
    cat1[col] = le.fit_transform(cat1[col])

# %%
cat1.head()
# Out:
#    job  marital  education  default  housing  loan  contact  month  \
# 0    1        1          2        0        2     0        0      6
# 1    7        2          3        0        0     0        1      6
# 2    7        1          3        0        2     0        1      4
# 3    7        1          2        0        1     1        1      4
# 4    0        1          6        0        2     0        0      7
#
#    day_of_week  poutcome
# 0            0         1
# 1            0         1
# 2            4         1
# 3            0         1
# 4            1         1

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()

# %%
target= le1.fit_transform(t)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y=pd.DataFrame(target,columns=['approved'])

# %%
y.head()
# Out:
#    approved
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
train_df=num.join(cat1)

# %%
train_df.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   30       487         2    999         0          -1.8          92.893
# 1   39       346         4    999         0           1.1          93.994
# 2   25       227         1    999         0           1.4          94.465
# 3   38        17         3    999         0           1.4          94.465
# 4   47        58         1    999         0          -0.1          93.200
#
#    cons.conf.idx  euribor3m  nr.employed  job  marital  education  default  \
# 0          -46.2      1.313       5099.1    1        1          2        0
# 1          -36.4      4.855       5191.0    7        2          3        0
# 2          -41.8      4.962       5228.1    7        1          3        0
# 3          -41.8      4.959       5228.1    7        1          2        0
# 4          -42.0      4.191       5195.8    0        1          6        0
#
#    housing  loan  contact  month  day_of_week  poutcome
# 0        2     0        0      6            0         1
# 1        0     0        1      6            0         1
# 2        2     0        1      4            4         1
# 3        1     1        1      4            0         1
# 4        2     0        0      7            1         1

# %%
y.approved.value_counts()
# Out:
# 0    3668
# 1     451
# Name: approved, dtype: int64

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# %%
smk=SMOTETomek(random_state=42)

# %%
data,target=smk.fit_resample(train_df,y)

# %%
print(data.shape,target.shape)
# Out:
# (7256, 20) (7256, 1)

# %%
#importing the spliting slibraries to split the data
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(data,target,random_state=104,test_size=0.2,shuffle=True)

# %%
#importing the requried model to fitand predict the data
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
model=clf.fit(x_train,y_train)

# %%
#pridict the data of train after fitting
y_pred = clf.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
accuracy_tr = accuracy_score(y_train, y_pred)
precision_tr = precision_score(y_train, y_pred, average='weighted')
recall_tr = recall_score(y_train, y_pred, average='weighted')
f1_tr = f1_score(y_train, y_pred, average='weighted')

# %%
print(f"Accuracy: {accuracy_tr:.2f}")
print(f"Precision: {precision_tr:.2f}")
print(f"Recall: {recall_tr:.2f}")
print(f"F1 Score: {f1_tr:.2f}")
# Out:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00

# %%
#pridict the data of test, after fitting
Y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
accuracy = accuracy_score(y_test, Y_pred)
precision = precision_score(y_test, Y_pred, average='weighted')
recall = recall_score(y_test, Y_pred, average='weighted')
f1 = f1_score(y_test, Y_pred, average='weighted')

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.92
# Precision: 0.92
# Recall: 0.92
# F1 Score: 0.92

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 4, 6, 8, 10],
    'min_samples_leaf': [1, 2, 4, 6, 8]
}

# %%
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, n_jobs=-1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'min_samples_leaf': [1, 2, 4, 6, 8],
#                          'min_samples_split': [2, 4, 6, 8, 10]})

# %%
g_pred=grid_search.predict(x_train)

# %%
#checking the performance metrics of the model for test data
accuracy = accuracy_score(y_train, g_pred)
precision = precision_score(y_train, g_pred, average='weighted')
recall = recall_score(y_train, g_pred, average='weighted')
f1 = f1_score(y_train, g_pred, average='weighted')

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.97
# Precision: 0.97
# Recall: 0.97
# F1 Score: 0.97

# %%
g_pred1=grid_search.predict(x_test)

# %%
#checking the performance metrics of the model for test data
accuracy = accuracy_score(y_test, g_pred1)
precision = precision_score(y_test, g_pred1, average='weighted')
recall = recall_score(y_test, g_pred1, average='weighted')
f1 = f1_score(y_test, g_pred1, average='weighted')

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.92
# Precision: 0.93
# Recall: 0.92
# F1 Score: 0.92
