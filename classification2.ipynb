# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_excel('/content/D1_file1.xlsx')
df.head()
# Out:
#       id ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0   9046          Yes        Private          Urban             228.69  36.6
# 1  51676          Yes  Self-employed          Rural             202.21   NaN
# 2  31112          Yes        Private          Rural             105.92  32.5
# 3  60182          Yes        Private          Urban             171.23  34.4
# 4   1665          Yes  Self-employed          Rural             174.12  24.0
#
#     smoking_status
# 0  formerly smoked
# 1     never smoked
# 2     never smoked
# 3           smokes
# 4     never smoked

# %%
df.shape
# Out:
# (5110, 7)

# %%
df1=pd.read_excel('/content/D1_file2.xlsx')
df1.head()
# Out:
#       id  gender   age
# 0   9046    Male  67.0
# 1  51676  Female  61.0
# 2  31112    Male  80.0
# 3  60182  Female  49.0
# 4   1665  Female  79.0

# %%
df1.shape
# Out:
# (5110, 3)

# %%
df2=pd.read_excel('/content/D1_file3.xlsx')
df2.head()
# Out:
#       id  hypertension  heart_disease
# 0   9046             0              1
# 1  51676             0              0
# 2  31112             0              1
# 3  60182             0              0
# 4   1665             1              0

# %%
df2.shape
# Out:
# (5110, 3)

# %%
df3=pd.read_excel('/content/D1_target.xlsx')
df3.head()
# Out:
#       id  stroke
# 0   9046       1
# 1  51676       1
# 2  31112       1
# 3  60182       1
# 4   1665       1

# %%
df3.shape
# Out:
# (5110, 2)

# %%
df11=pd.merge(df,df1)
df11.head()
# Out:
#       id ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0   9046          Yes        Private          Urban             228.69  36.6
# 1  51676          Yes  Self-employed          Rural             202.21   NaN
# 2  31112          Yes        Private          Rural             105.92  32.5
# 3  60182          Yes        Private          Urban             171.23  34.4
# 4   1665          Yes  Self-employed          Rural             174.12  24.0
#
#     smoking_status  gender   age
# 0  formerly smoked    Male  67.0
# 1     never smoked  Female  61.0
# 2     never smoked    Male  80.0
# 3           smokes  Female  49.0
# 4     never smoked  Female  79.0

# %%
df12=pd.merge(df11,df2)
df12.head()
# Out:
#       id ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0   9046          Yes        Private          Urban             228.69  36.6
# 1  51676          Yes  Self-employed          Rural             202.21   NaN
# 2  31112          Yes        Private          Rural             105.92  32.5
# 3  60182          Yes        Private          Urban             171.23  34.4
# 4   1665          Yes  Self-employed          Rural             174.12  24.0
#
#     smoking_status  gender   age  hypertension  heart_disease
# 0  formerly smoked    Male  67.0             0              1
# 1     never smoked  Female  61.0             0              0
# 2     never smoked    Male  80.0             0              1
# 3           smokes  Female  49.0             0              0
# 4     never smoked  Female  79.0             1              0

# %%
final_df=pd.merge(df12,df3,)
final_df.head()
# Out:
#       id ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0   9046          Yes        Private          Urban             228.69  36.6
# 1  51676          Yes  Self-employed          Rural             202.21   NaN
# 2  31112          Yes        Private          Rural             105.92  32.5
# 3  60182          Yes        Private          Urban             171.23  34.4
# 4   1665          Yes  Self-employed          Rural             174.12  24.0
#
#     smoking_status  gender   age  hypertension  heart_disease  stroke
# 0  formerly smoked    Male  67.0             0              1       1
# 1     never smoked  Female  61.0             0              0       1
# 2     never smoked    Male  80.0             0              1       1
# 3           smokes  Female  49.0             0              0       1
# 4     never smoked  Female  79.0             1              0       1

# %%
final_df.isnull().sum()
# Out:
# id                     0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# stroke                 0
# dtype: int64

# %%
final_df.stroke.value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
final_df.describe()
# Out:
#                  id  avg_glucose_level          bmi          age  \
# count   5110.000000        5110.000000  4909.000000  5110.000000
# mean   36517.829354         106.147677    28.893237    43.226614
# std    21161.721625          45.283560     7.854067    22.612647
# min       67.000000          55.120000    10.300000     0.080000
# 25%    17741.250000          77.245000    23.500000    25.000000
# 50%    36932.000000          91.885000    28.100000    45.000000
# 75%    54682.000000         114.090000    33.100000    61.000000
# max    72940.000000         271.740000    97.600000    82.000000
#
#        hypertension  heart_disease       stroke
# count   5110.000000    5110.000000  5110.000000
# mean       0.097456       0.054012     0.048728
# std        0.296607       0.226063     0.215320
# min        0.000000       0.000000     0.000000
# 25%        0.000000       0.000000     0.000000
# 50%        0.000000       0.000000     0.000000
# 75%        0.000000       0.000000     0.000000
# max        1.000000       1.000000     1.000000

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   ever_married       5110 non-null   object
#  2   work_type          5110 non-null   object
#  3   Residence_type     5110 non-null   object
#  4   avg_glucose_level  5110 non-null   float64
#  5   bmi                4909 non-null   float64
#  6   smoking_status     5110 non-null   object
#  7   gender             5110 non-null   object
#  8   age                5110 non-null   float64
#  9   hypertension       5110 non-null   int64
#  10  heart_disease      5110 non-null   int64
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 519.0+ KB

# %%
final_df.dtypes
# Out:
# id                     int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# stroke                 int64
# dtype: object

# %%
#correlation between features 
final_df.corr()
# Out:
#                          id  avg_glucose_level       bmi       age  \
# id                 1.000000           0.001092  0.003084  0.003538
# avg_glucose_level  0.001092           1.000000  0.175502  0.238171
# bmi                0.003084           0.175502  1.000000  0.333398
# age                0.003538           0.238171  0.333398  1.000000
# hypertension       0.003550           0.174474  0.167811  0.276398
# heart_disease     -0.001296           0.161857  0.041357  0.263796
# stroke             0.006388           0.131945  0.042374  0.245257
#
#                    hypertension  heart_disease    stroke
# id                     0.003550      -0.001296  0.006388
# avg_glucose_level      0.174474       0.161857  0.131945
# bmi                    0.167811       0.041357  0.042374
# age                    0.276398       0.263796  0.245257
# hypertension           1.000000       0.108306  0.127904
# heart_disease          0.108306       1.000000  0.134914
# stroke                 0.127904       0.134914  1.000000

# %%
# features correlation with  visualization using seaborn
sns.set(rc={'figure.figsize': (20, 10)})
sns .heatmap(final_df.corr(),annot=True,annot_kws={'size':12},cmap="YlGnBu")
plt.show()

# %%
#to get only numerical cols 
num=final_df._get_numeric_data() 
num.head()
# Out:
#       id  avg_glucose_level   bmi   age  hypertension  heart_disease  stroke
# 0   9046             228.69  36.6  67.0             0              1       1
# 1  51676             202.21   NaN  61.0             0              0       1
# 2  31112             105.92  32.5  80.0             0              1       1
# 3  60182             171.23  34.4  49.0             0              0       1
# 4   1665             174.12  24.0  79.0             1              0       1

# %%
num.fillna(num.mean(), inplace=True)

# %%
num.isnull().sum()
# Out:
# id                   0
# avg_glucose_level    0
# bmi                  0
# age                  0
# hypertension         0
# heart_disease        0
# stroke               0
# dtype: int64

# %%
num.head()
# Out:
#       id  avg_glucose_level        bmi   age  hypertension  heart_disease  \
# 0   9046             228.69  36.600000  67.0             0              1
# 1  51676             202.21  28.893237  61.0             0              0
# 2  31112             105.92  32.500000  80.0             0              1
# 3  60182             171.23  34.400000  49.0             0              0
# 4   1665             174.12  24.000000  79.0             1              0
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
num=num.drop(['id'],axis=1)

# %%
num1=num.drop(['stroke'],axis=1)

# %%
#assign the target variable to t
t=num.drop(num1,axis=1)

# %%
#to get only cat cols and changing it as categorical from object 
cat=final_df.drop(num,axis=1)
cat=cat.astype('category')
cat.head()
# Out:
#       id ever_married      work_type Residence_type   smoking_status  gender
# 0   9046          Yes        Private          Urban  formerly smoked    Male
# 1  51676          Yes  Self-employed          Rural     never smoked  Female
# 2  31112          Yes        Private          Rural     never smoked    Male
# 3  60182          Yes        Private          Urban           smokes  Female
# 4   1665          Yes  Self-employed          Rural     never smoked  Female

# %%
cat.isnull().sum()
# Out:
# id                0
# ever_married      0
# work_type         0
# Residence_type    0
# smoking_status    0
# gender            0
# dtype: int64

# %%
cat.gender.value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
cat=cat.drop(['id'],axis=1)

# %%
cat_col=cat.columns
cat_col
# Out:
# Index(['ever_married', 'work_type', 'Residence_type', 'smoking_status',
#        'gender'],
#       dtype='object')

# %%
#converting the target variable as num by using Labelencoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in cat_col:
    cat[col] = le.fit_transform(cat[col])

# %%
cat.head()
# Out:
#    ever_married  work_type  Residence_type  smoking_status  gender
# 0             1          2               1               1       1
# 1             1          3               0               2       0
# 2             1          2               0               2       1
# 3             1          2               1               3       0
# 4             1          3               0               2       0

# %%
train_df=num.join(cat)

# %%
train_df.head()
# Out:
#    avg_glucose_level        bmi   age  hypertension  heart_disease  stroke  \
# 0             228.69  36.600000  67.0             0              1       1
# 1             202.21  28.893237  61.0             0              0       1
# 2             105.92  32.500000  80.0             0              1       1
# 3             171.23  34.400000  49.0             0              0       1
# 4             174.12  24.000000  79.0             1              0       1
#
#    ever_married  work_type  Residence_type  smoking_status  gender
# 0             1          2               1               1       1
# 1             1          3               0               2       0
# 2             1          2               0               2       1
# 3             1          2               1               3       0
# 4             1          3               0               2       0

# %%
X=train_df.drop(['stroke'],axis=1)
Y=train_df.drop(X,axis=1)

# %%
X.head()
# Out:
#    avg_glucose_level        bmi   age  hypertension  heart_disease  \
# 0             228.69  36.600000  67.0             0              1
# 1             202.21  28.893237  61.0             0              0
# 2             105.92  32.500000  80.0             0              1
# 3             171.23  34.400000  49.0             0              0
# 4             174.12  24.000000  79.0             1              0
#
#    ever_married  work_type  Residence_type  smoking_status  gender
# 0             1          2               1               1       1
# 1             1          3               0               2       0
# 2             1          2               0               2       1
# 3             1          2               1               3       0
# 4             1          3               0               2       0

# %%
Y.head()
# Out:
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# %%
smk=SMOTETomek(random_state=42)

# %%
data,target=smk.fit_resample(X,Y)

# %%
print(data.shape,target.shape)
# Out:
# (9626, 10) (9626, 1)

# %%
target.stroke.value_counts()
# Out:
# 1    4813
# 0    4813
# Name: stroke, dtype: int64

# %%
#importing the spliting slibraries to split the data
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(data,target,random_state=104,test_size=0.3,shuffle=True)

# %%
#importing the requried model to fitand predict the data
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
model=clf.fit(x_train,y_train)

# %%
#pridict the data of train after fitting
y_pred = clf.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
accuracy_tr = accuracy_score(y_train, y_pred)
precision_tr = precision_score(y_train, y_pred, average='weighted')
recall_tr = recall_score(y_train, y_pred, average='weighted')
f1_tr = f1_score(y_train, y_pred, average='weighted')

# %%
print(f"Accuracy: {accuracy_tr:.2f}")
print(f"Precision: {precision_tr:.2f}")
print(f"Recall: {recall_tr:.2f}")
print(f"F1 Score: {f1_tr:.2f}")
# Out:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00

# %%
#pridict the data of test, after fitting
Y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
accuracy = accuracy_score(y_test, Y_pred)
precision = precision_score(y_test, Y_pred, average='weighted')
recall = recall_score(y_test, Y_pred, average='weighted')
f1 = f1_score(y_test, Y_pred, average='weighted')

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.91
# Precision: 0.91
# Recall: 0.91
# F1 Score: 0.91

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 4, 6, 8, 10],
    'min_samples_leaf': [1, 2, 4, 6, 8]
}

# %%
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, n_jobs=-1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'min_samples_leaf': [1, 2, 4, 6, 8],
#                          'min_samples_split': [2, 4, 6, 8, 10]})

# %%
g_pred=grid_search.predict(x_train)

# %%
#checking the performance metrics of the model for test data
accuracy = accuracy_score(y_train, g_pred)
precision = precision_score(y_train, g_pred, average='weighted')
recall = recall_score(y_train, g_pred, average='weighted')
f1 = f1_score(y_train, g_pred, average='weighted')

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.93
# Precision: 0.94
# Recall: 0.93
# F1 Score: 0.93

# %%
g_pred1=grid_search.predict(x_test)

# %%
#checking the performance metrics of the model for test data
accuracy = accuracy_score(y_test, g_pred1)
precision = precision_score(y_test, g_pred1, average='weighted')
recall = recall_score(y_test, g_pred1, average='weighted')
f1 = f1_score(y_test, g_pred1, average='weighted')

# %%
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.89
# Precision: 0.89
# Recall: 0.89
# F1 Score: 0.89
